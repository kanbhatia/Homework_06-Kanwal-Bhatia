# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# # Analysis
# Oberservation 1: The temperature increases as u get closer to ~25 Latitude. This confirms the initial hypothesis of temperature being hottest at the equator.
#
# Oberservation 2: Humidity does not vary significatly when compared with the latitude of the cities. However we can state the humidity levels around the world are mostly between 40 - 100%
#
# Oberservation 3: Latitude does not have a significant affect on wind speeds.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests as rp
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
name =[]
cloudiness =[] 
country =[] 
date =[] 
humidity =[] 
lat = [] 
lng =[] 
max_temp =[] 
wind_speed =[] 

print("Begining Data Retrieval\n---------------------------")
counter = 1
for city in cities:
    #printing processing records
    try:
        responce = rp.get(f"{url}appid={api_key}&units=imperial&q={city}").json()
        base = counter//50
        print(f"Processing Record {counter - base*50} of set {base+1} | {city}")
        counter += 1
        name.append(responce["name"])
        cloudiness.append(responce["clouds"]["all"])
        country.append(responce["sys"]["country"])
        date.append(responce["dt"])
        humidity.append(responce["main"]["humidity"])
        lat.append(responce["coord"]["lat"])
        lng.append(responce["coord"]["lon"])
        max_temp.append(responce["main"]["temp_max"])
        wind_speed.append(responce["wind"]["speed"])
    except Exception as e:
        print("City not found. Skipping...")
    
print('''
    ---------------------------
    Data Retrival Complete
    ---------------------------
''')
# Out:
# Begining Data Retrieval
# ---------------------------
# Processing Record 1 of set 1 | arraial do cabo
# Processing Record 2 of set 1 | jamestown
# Processing Record 3 of set 1 | chokurdakh
# Processing Record 4 of set 1 | atuona
# Processing Record 5 of set 1 | tuktoyaktuk
# Processing Record 6 of set 1 | katsuura
# Processing Record 7 of set 1 | hilo
# Processing Record 8 of set 1 | fukue
# Processing Record 9 of set 1 | nikolskoye
# Processing Record 10 of set 1 | bluff
# Processing Record 11 of set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of set 1 | taoudenni
# Processing Record 14 of set 1 | tiksi
# Processing Record 15 of set 1 | siuna
# Processing Record 16 of set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of set 1 | rikitea
# Processing Record 18 of set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of set 1 | aklavik
# Processing Record 20 of set 1 | catalina
# Processing Record 21 of set 1 | punta arenas
# Processing Record 22 of set 1 | new norfolk
# Processing Record 23 of set 1 | vaini
# Processing Record 24 of set 1 | ushuaia
# Processing Record 25 of set 1 | ponnani
# Processing Record 26 of set 1 | nantucket
# Processing Record 27 of set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of set 1 | mataura
# Processing Record 29 of set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of set 1 | lampazos de naranjo
# Processing Record 31 of set 1 | albany
# Processing Record 32 of set 1 | lolua
# City not found. Skipping...
# Processing Record 33 of set 1 | butaritari
# Processing Record 34 of set 1 | avaton
# Processing Record 35 of set 1 | balkhash
# Processing Record 36 of set 1 | sawakin
# Processing Record 37 of set 1 | salalah
# Processing Record 38 of set 1 | kaitangata
# Processing Record 39 of set 1 | kijang
# Processing Record 40 of set 1 | hobart
# Processing Record 41 of set 1 | mahibadhoo
# Processing Record 42 of set 1 | nyurba
# Processing Record 43 of set 1 | lompoc
# Processing Record 44 of set 1 | kang
# Processing Record 45 of set 1 | tuy hoa
# Processing Record 46 of set 1 | geraldton
# Processing Record 47 of set 1 | coahuayana
# Processing Record 48 of set 1 | kurumkan
# Processing Record 49 of set 1 | orlik
# Processing Record 0 of set 2 | ossora
# Processing Record 1 of set 2 | mahebourg
# Processing Record 2 of set 2 | deputatskiy
# Processing Record 3 of set 2 | luderitz
# Processing Record 4 of set 2 | sao joao da barra
# Processing Record 5 of set 2 | nioro
# Processing Record 6 of set 2 | hermanus
# Processing Record 7 of set 2 | busselton
# Processing Record 8 of set 2 | thai nguyen
# Processing Record 9 of set 2 | lebu
# Processing Record 10 of set 2 | hithadhoo
# Processing Record 11 of set 2 | ocotlan
# Processing Record 12 of set 2 | provideniya
# Processing Record 13 of set 2 | kotido
# Processing Record 14 of set 2 | qaanaaq
# Processing Record 15 of set 2 | san patricio
# Processing Record 16 of set 2 | kharitonovo
# Processing Record 17 of set 2 | upernavik
# Processing Record 18 of set 2 | husavik
# Processing Record 19 of set 2 | hasaki
# Processing Record 20 of set 2 | carnarvon
# Processing Record 21 of set 2 | hastings
# Processing Record 22 of set 2 | bilibino
# Processing Record 23 of set 2 | puerto ayora
# Processing Record 24 of set 2 | naftalan
# Processing Record 25 of set 2 | juneau
# Processing Record 26 of set 2 | les escoumins
# Processing Record 27 of set 2 | laguna
# Processing Record 28 of set 2 | zhongshu
# Processing Record 29 of set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of set 2 | paamiut
# Processing Record 31 of set 2 | half moon bay
# Processing Record 32 of set 2 | tumannyy
# City not found. Skipping...
# Processing Record 33 of set 2 | ajdabiya
# Processing Record 34 of set 2 | scarborough
# Processing Record 35 of set 2 | kyzyl
# Processing Record 36 of set 2 | sao filipe
# Processing Record 37 of set 2 | havoysund
# Processing Record 38 of set 2 | umuarama
# Processing Record 39 of set 2 | santa maria
# Processing Record 40 of set 2 | malwan
# City not found. Skipping...
# Processing Record 41 of set 2 | mitu
# Processing Record 42 of set 2 | port elizabeth
# Processing Record 43 of set 2 | batemans bay
# Processing Record 44 of set 2 | saint-philippe
# Processing Record 45 of set 2 | ponta do sol
# Processing Record 46 of set 2 | tessalit
# Processing Record 47 of set 2 | touros
# Processing Record 48 of set 2 | grand river south east
# City not found. Skipping...
# Processing Record 49 of set 2 | ostrovnoy
# Processing Record 0 of set 3 | coquimbo
# Processing Record 1 of set 3 | marystown
# Processing Record 2 of set 3 | lagunas
# Processing Record 3 of set 3 | vilhena
# Processing Record 4 of set 3 | cape town
# Processing Record 5 of set 3 | margate
# Processing Record 6 of set 3 | jacqueville
# Processing Record 7 of set 3 | saint anthony
# Processing Record 8 of set 3 | tasiilaq
# Processing Record 9 of set 3 | acapulco
# Processing Record 10 of set 3 | port stanley
# Processing Record 11 of set 3 | yumen
# Processing Record 12 of set 3 | kapaa
# Processing Record 13 of set 3 | yellowknife
# Processing Record 14 of set 3 | nanfeng
# Processing Record 15 of set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of set 3 | chama
# Processing Record 17 of set 3 | suntar
# Processing Record 18 of set 3 | bilma
# Processing Record 19 of set 3 | bathsheba
# Processing Record 20 of set 3 | dikson
# Processing Record 21 of set 3 | guarapari
# Processing Record 22 of set 3 | verkhnyaya inta
# Processing Record 23 of set 3 | cherskiy
# Processing Record 24 of set 3 | omsukchan
# Processing Record 25 of set 3 | olinda
# Processing Record 26 of set 3 | torbay
# Processing Record 27 of set 3 | bredasdorp
# Processing Record 28 of set 3 | gweru
# Processing Record 29 of set 3 | oistins
# Processing Record 30 of set 3 | burica
# City not found. Skipping...
# Processing Record 31 of set 3 | gravdal
# Processing Record 32 of set 3 | dera baba nanak
# City not found. Skipping...
# Processing Record 33 of set 3 | skibbereen
# Processing Record 34 of set 3 | hofn
# Processing Record 35 of set 3 | saint george
# Processing Record 36 of set 3 | garachine
# Processing Record 37 of set 3 | lingao
# Processing Record 38 of set 3 | namatanai
# Processing Record 39 of set 3 | victoria
# Processing Record 40 of set 3 | maraba
# Processing Record 41 of set 3 | vanimo
# Processing Record 42 of set 3 | rio cuarto
# Processing Record 43 of set 3 | gat
# Processing Record 44 of set 3 | jasper
# Processing Record 45 of set 3 | salinopolis
# Processing Record 46 of set 3 | rantauprapat
# Processing Record 47 of set 3 | saldanha
# Processing Record 48 of set 3 | bonavista
# Processing Record 49 of set 3 | ngunguru
# Processing Record 0 of set 4 | soe
# Processing Record 1 of set 4 | fairbanks
# Processing Record 2 of set 4 | jiddah
# City not found. Skipping...
# Processing Record 3 of set 4 | zhigansk
# Processing Record 4 of set 4 | hvammstangi
# City not found. Skipping...
# Processing Record 5 of set 4 | englewood
# Processing Record 6 of set 4 | leningradskiy
# Processing Record 7 of set 4 | lorengau
# Processing Record 8 of set 4 | baruun-urt
# Processing Record 9 of set 4 | east london
# Processing Record 10 of set 4 | saleaula
# City not found. Skipping...
# Processing Record 11 of set 4 | esperance
# Processing Record 12 of set 4 | clarence town
# Processing Record 13 of set 4 | burnie
# Processing Record 14 of set 4 | fort nelson
# Processing Record 15 of set 4 | ilhabela
# Processing Record 16 of set 4 | grand centre
# City not found. Skipping...
# Processing Record 17 of set 4 | barra do garcas
# Processing Record 18 of set 4 | kismayo
# City not found. Skipping...
# Processing Record 19 of set 4 | port alfred
# Processing Record 20 of set 4 | port augusta
# Processing Record 21 of set 4 | ribeira grande
# Processing Record 22 of set 4 | alofi
# Processing Record 23 of set 4 | bambous virieux
# Processing Record 24 of set 4 | itacoatiara
# Processing Record 25 of set 4 | rabo de peixe
# Processing Record 26 of set 4 | asheboro
# Processing Record 27 of set 4 | chuy
# Processing Record 28 of set 4 | houma
# Processing Record 29 of set 4 | ancud
# Processing Record 30 of set 4 | pangkalanbuun
# Processing Record 31 of set 4 | georgetown
# Processing Record 32 of set 4 | great yarmouth
# Processing Record 33 of set 4 | miedzyrzecz
# Processing Record 34 of set 4 | corcoran
# Processing Record 35 of set 4 | berlevag
# Processing Record 36 of set 4 | balabac
# Processing Record 37 of set 4 | xining
# Processing Record 38 of set 4 | klaksvik
# Processing Record 39 of set 4 | guthrie
# Processing Record 40 of set 4 | nome
# Processing Record 41 of set 4 | mount isa
# Processing Record 42 of set 4 | narsaq
# Processing Record 43 of set 4 | ucluelet
# Processing Record 44 of set 4 | altus
# Processing Record 45 of set 4 | ngukurr
# City not found. Skipping...
# Processing Record 46 of set 4 | norman wells
# Processing Record 47 of set 4 | lock haven
# Processing Record 48 of set 4 | maragogi
# Processing Record 49 of set 4 | poum
# Processing Record 0 of set 5 | necochea
# Processing Record 1 of set 5 | chernyshevskiy
# Processing Record 2 of set 5 | krivosheino
# Processing Record 3 of set 5 | novoagansk
# Processing Record 4 of set 5 | tubinskiy
# Processing Record 5 of set 5 | montemorelos
# Processing Record 6 of set 5 | riyadh
# Processing Record 7 of set 5 | longyearbyen
# Processing Record 8 of set 5 | kommunisticheskiy
# Processing Record 9 of set 5 | wum
# Processing Record 10 of set 5 | vallenar
# Processing Record 11 of set 5 | jega
# Processing Record 12 of set 5 | sawtell
# Processing Record 13 of set 5 | vardo
# Processing Record 14 of set 5 | alice springs
# Processing Record 15 of set 5 | cholet
# Processing Record 16 of set 5 | iberia
# Processing Record 17 of set 5 | khatanga
# Processing Record 18 of set 5 | payson
# Processing Record 19 of set 5 | atka
# City not found. Skipping...
# Processing Record 20 of set 5 | lahad datu
# Processing Record 21 of set 5 | coihaique
# Processing Record 22 of set 5 | pangnirtung
# Processing Record 23 of set 5 | padang
# Processing Record 24 of set 5 | inhambane
# Processing Record 25 of set 5 | sorland
# Processing Record 26 of set 5 | shestakovo
# Processing Record 27 of set 5 | barrow
# Processing Record 28 of set 5 | shenjiamen
# Processing Record 29 of set 5 | nishihara
# Processing Record 30 of set 5 | san carlos de bariloche
# Processing Record 31 of set 5 | polson
# Processing Record 32 of set 5 | puerto colombia
# Processing Record 33 of set 5 | hamilton
# Processing Record 34 of set 5 | saskylakh
# Processing Record 35 of set 5 | bethel
# Processing Record 36 of set 5 | santa helena de goias
# Processing Record 37 of set 5 | kihei
# Processing Record 38 of set 5 | of
# City not found. Skipping...
# Processing Record 39 of set 5 | samusu
# City not found. Skipping...
# Processing Record 40 of set 5 | wangdiphodrang
# City not found. Skipping...
# Processing Record 41 of set 5 | iracoubo
# Processing Record 42 of set 5 | loandjili
# Processing Record 43 of set 5 | haines junction
# Processing Record 44 of set 5 | tsihombe
# City not found. Skipping...
# Processing Record 45 of set 5 | ukiah
# Processing Record 46 of set 5 | flin flon
# Processing Record 47 of set 5 | killybegs
# Processing Record 48 of set 5 | tonekabon
# Processing Record 49 of set 5 | pitimbu
# Processing Record 0 of set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of set 6 | te anau
# Processing Record 2 of set 6 | portobelo
# Processing Record 3 of set 6 | lagos
# Processing Record 4 of set 6 | newport
# Processing Record 5 of set 6 | palmas
# Processing Record 6 of set 6 | port hedland
# Processing Record 7 of set 6 | meulaboh
# Processing Record 8 of set 6 | faanui
# Processing Record 9 of set 6 | fortuna
# Processing Record 10 of set 6 | viligili
# City not found. Skipping...
# Processing Record 11 of set 6 | bibiani
# Processing Record 12 of set 6 | tazovskiy
# Processing Record 13 of set 6 | talnakh
# Processing Record 14 of set 6 | oinoussai
# City not found. Skipping...
# Processing Record 15 of set 6 | moerai
# Processing Record 16 of set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of set 6 | huarmey
# Processing Record 18 of set 6 | suhut
# Processing Record 19 of set 6 | kurkino
# Processing Record 20 of set 6 | mar del plata
# Processing Record 21 of set 6 | okakarara
# Processing Record 22 of set 6 | troitskoye
# Processing Record 23 of set 6 | sabha
# Processing Record 24 of set 6 | itarema
# Processing Record 25 of set 6 | pisco
# Processing Record 26 of set 6 | severo-kurilsk
# Processing Record 27 of set 6 | tautira
# Processing Record 28 of set 6 | yining
# Processing Record 29 of set 6 | bereslavka
# Processing Record 30 of set 6 | makushino
# Processing Record 31 of set 6 | san matias
# Processing Record 32 of set 6 | zapolyarnyy
# Processing Record 33 of set 6 | orhei
# Processing Record 34 of set 6 | koslan
# Processing Record 35 of set 6 | kelowna
# Processing Record 36 of set 6 | pleasant point
# Processing Record 37 of set 6 | ahipara
# Processing Record 38 of set 6 | bandarbeyla
# Processing Record 39 of set 6 | souillac
# Processing Record 40 of set 6 | sale
# Processing Record 41 of set 6 | pemberton
# Processing Record 42 of set 6 | adrar
# Processing Record 43 of set 6 | amderma
# City not found. Skipping...
# Processing Record 44 of set 6 | holland
# Processing Record 45 of set 6 | srednekolymsk
# Processing Record 46 of set 6 | makakilo city
# Processing Record 47 of set 6 | sinnamary
# Processing Record 48 of set 6 | sadao
# Processing Record 49 of set 6 | igrim
# Processing Record 0 of set 7 | udachnyy
# Processing Record 1 of set 7 | uchiza
# Processing Record 2 of set 7 | castro
# Processing Record 3 of set 7 | marv dasht
# City not found. Skipping...
# Processing Record 4 of set 7 | areosa
# Processing Record 5 of set 7 | tabuk
# Processing Record 6 of set 7 | wuwei
# Processing Record 7 of set 7 | iwanai
# Processing Record 8 of set 7 | yangambi
# Processing Record 9 of set 7 | tefe
# Processing Record 10 of set 7 | avarua
# Processing Record 11 of set 7 | caravelas
# Processing Record 12 of set 7 | kavieng
# Processing Record 13 of set 7 | waitati
# Processing Record 14 of set 7 | broome
# Processing Record 15 of set 7 | moron
# Processing Record 16 of set 7 | khani
# Processing Record 17 of set 7 | bushehr
# Processing Record 18 of set 7 | borogontsy
# Processing Record 19 of set 7 | lajas
# Processing Record 20 of set 7 | chapais
# Processing Record 21 of set 7 | bonthe
# Processing Record 22 of set 7 | lengshuitan
# Processing Record 23 of set 7 | pevek
# Processing Record 24 of set 7 | sitka
# Processing Record 25 of set 7 | jumla
# Processing Record 26 of set 7 | sorvag
# City not found. Skipping...
# Processing Record 27 of set 7 | meadow lake
# Processing Record 28 of set 7 | koshurnikovo
# Processing Record 29 of set 7 | zhezkazgan
# Processing Record 30 of set 7 | codrington
# Processing Record 31 of set 7 | tura
# Processing Record 32 of set 7 | kodiak
# Processing Record 33 of set 7 | novyy urgal
# Processing Record 34 of set 7 | isangel
# Processing Record 35 of set 7 | pochinki
# Processing Record 36 of set 7 | komatipoort
# Processing Record 37 of set 7 | lamu
# Processing Record 38 of set 7 | shimoda
# Processing Record 39 of set 7 | kuusamo
# Processing Record 40 of set 7 | shiraz
# Processing Record 41 of set 7 | port moresby
# Processing Record 42 of set 7 | altea
# Processing Record 43 of set 7 | atherton
# Processing Record 44 of set 7 | nerchinskiy zavod
# Processing Record 45 of set 7 | ternate
# Processing Record 46 of set 7 | tuatapere
# Processing Record 47 of set 7 | airai
# Processing Record 48 of set 7 | tilichiki
# Processing Record 49 of set 7 | sobolevo
# Processing Record 0 of set 8 | nesna
# Processing Record 1 of set 8 | zhob
# Processing Record 2 of set 8 | komsomolskiy
# Processing Record 3 of set 8 | andilamena
# Processing Record 4 of set 8 | kutum
# Processing Record 5 of set 8 | ruatoria
# City not found. Skipping...
# Processing Record 6 of set 8 | roma
# Processing Record 7 of set 8 | mumbwa
# Processing Record 8 of set 8 | nemuro
# Processing Record 9 of set 8 | hovd
# Processing Record 10 of set 8 | kamenka
# Processing Record 11 of set 8 | martapura
# Processing Record 12 of set 8 | launceston
# Processing Record 13 of set 8 | rawannawi
# City not found. Skipping...
# Processing Record 14 of set 8 | san policarpo
# Processing Record 15 of set 8 | angoche
# Processing Record 16 of set 8 | nanning
# Processing Record 17 of set 8 | tres arroyos
# Processing Record 18 of set 8 | kanashevo
# Processing Record 19 of set 8 | miri
# Processing Record 20 of set 8 | thompson
# Processing Record 21 of set 8 | vila franca do campo
# Processing Record 22 of set 8 | port lincoln
# Processing Record 23 of set 8 | nanortalik
# Processing Record 24 of set 8 | san lorenzo
# Processing Record 25 of set 8 | wewak
# Processing Record 26 of set 8 | andevoranto
# City not found. Skipping...
# Processing Record 27 of set 8 | puerto suarez
# Processing Record 28 of set 8 | atar
# Processing Record 29 of set 8 | zelenoborskiy
# Processing Record 30 of set 8 | yar-sale
# Processing Record 31 of set 8 | roebourne
# Processing Record 32 of set 8 | vanderhoof
# Processing Record 33 of set 8 | alta
# Processing Record 34 of set 8 | oudtshoorn
# Processing Record 35 of set 8 | katobu
# Processing Record 36 of set 8 | mitchell
# Processing Record 37 of set 8 | ilulissat
# Processing Record 38 of set 8 | rondonopolis
# Processing Record 39 of set 8 | banda aceh
# Processing Record 40 of set 8 | cayenne
# Processing Record 41 of set 8 | olafsvik
# City not found. Skipping...
# Processing Record 42 of set 8 | rocha
# Processing Record 43 of set 8 | kiunga
# Processing Record 44 of set 8 | bambanglipuro
# Processing Record 45 of set 8 | chauny
# Processing Record 46 of set 8 | saurimo
# Processing Record 47 of set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of set 8 | qaqortoq
# Processing Record 49 of set 8 | hinton
# Processing Record 0 of set 9 | tateyama
# Processing Record 1 of set 9 | uruzgan
# Processing Record 2 of set 9 | alugan
# Processing Record 3 of set 9 | korem
# Processing Record 4 of set 9 | castanos
# Processing Record 5 of set 9 | evensk
# Processing Record 6 of set 9 | saint-joseph
# Processing Record 7 of set 9 | bengkulu
# City not found. Skipping...
# Processing Record 8 of set 9 | rudnogorsk
# Processing Record 9 of set 9 | hambantota
# Processing Record 10 of set 9 | pafos
# City not found. Skipping...
# Processing Record 11 of set 9 | iqaluit
# Processing Record 12 of set 9 | tucupita
# Processing Record 13 of set 9 | herat
# Processing Record 14 of set 9 | bongor
# Processing Record 15 of set 9 | kahului
# Processing Record 16 of set 9 | den helder
# Processing Record 17 of set 9 | sebezh
# Processing Record 18 of set 9 | luanda
# Processing Record 19 of set 9 | edson
# Processing Record 20 of set 9 | kohima
# Processing Record 21 of set 9 | zhaocheng
# City not found. Skipping...
# Processing Record 22 of set 9 | stromness
# Processing Record 23 of set 9 | rosarito
# Processing Record 24 of set 9 | wanaka
# Processing Record 25 of set 9 | aflu
# City not found. Skipping...
# Processing Record 26 of set 9 | longview
# Processing Record 27 of set 9 | barentsburg
# City not found. Skipping...
# Processing Record 28 of set 9 | vaitupu
# City not found. Skipping...
# Processing Record 29 of set 9 | oranjemund
# Processing Record 30 of set 9 | vasto
# Processing Record 31 of set 9 | cairns
# Processing Record 32 of set 9 | zharkent
# Processing Record 33 of set 9 | alpatovo
# Processing Record 34 of set 9 | les cayes
# Processing Record 35 of set 9 | hollabrunn
# Processing Record 36 of set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 37 of set 9 | waipawa
# Processing Record 38 of set 9 | sheltozero
# Processing Record 39 of set 9 | neuquen
# Processing Record 40 of set 9 | ambon
# Processing Record 41 of set 9 | peniche
# Processing Record 42 of set 9 | mount gambier
# Processing Record 43 of set 9 | pontianak
# Processing Record 44 of set 9 | tasbuget
# City not found. Skipping...
# Processing Record 45 of set 9 | alamor
# Processing Record 46 of set 9 | simoes
# Processing Record 47 of set 9 | khuzhir
# Processing Record 48 of set 9 | temyasovo
# Processing Record 49 of set 9 | great falls
# Processing Record 0 of set 10 | lodwar
# Processing Record 1 of set 10 | kokopo
# Processing Record 2 of set 10 | naze
# Processing Record 3 of set 10 | sur
# Processing Record 4 of set 10 | castro alves
# Processing Record 5 of set 10 | sioux lookout
# Processing Record 6 of set 10 | fuling
# Processing Record 7 of set 10 | marzuq
# Processing Record 8 of set 10 | itoman
# Processing Record 9 of set 10 | pangai
# Processing Record 10 of set 10 | dolbeau
# City not found. Skipping...
# Processing Record 11 of set 10 | petropavlovsk-kamchatskiy
# Processing Record 12 of set 10 | nchelenge
# Processing Record 13 of set 10 | harper
# Processing Record 14 of set 10 | moose factory
# Processing Record 15 of set 10 | safonovo
# Processing Record 16 of set 10 | san cristobal
# Processing Record 17 of set 10 | wangqing
# Processing Record 18 of set 10 | porto nacional
# Processing Record 19 of set 10 | derzhavinsk
# Processing Record 20 of set 10 | dinsor
# City not found. Skipping...
# Processing Record 21 of set 10 | rabak
# Processing Record 22 of set 10 | vrangel
# Processing Record 23 of set 10 | nyrob
# Processing Record 24 of set 10 | fontem
# Processing Record 25 of set 10 | sandpoint
# Processing Record 26 of set 10 | kearney
# Processing Record 27 of set 10 | mae hong son
# Processing Record 28 of set 10 | talaya
# Processing Record 29 of set 10 | zottegem
# Processing Record 30 of set 10 | tuljapur
# Processing Record 31 of set 10 | kungurtug
# Processing Record 32 of set 10 | tekeli
# Processing Record 33 of set 10 | lerwick
# Processing Record 34 of set 10 | constitucion
# Processing Record 35 of set 10 | hoquiam
# Processing Record 36 of set 10 | nuevo progreso
# Processing Record 37 of set 10 | melfort
# Processing Record 38 of set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of set 10 | pamulang
# Processing Record 40 of set 10 | lakeville
# Processing Record 41 of set 10 | najran
# Processing Record 42 of set 10 | rio grande
# Processing Record 43 of set 10 | vila velha
# Processing Record 44 of set 10 | port hardy
# Processing Record 45 of set 10 | clyde river
# Processing Record 46 of set 10 | lagoa
# Processing Record 47 of set 10 | blagoyevo
# Processing Record 48 of set 10 | pingliang
# Processing Record 49 of set 10 | ziyamet
# City not found. Skipping...
# Processing Record 0 of set 11 | galle
# Processing Record 1 of set 11 | pangody
# Processing Record 2 of set 11 | allapalli
# Processing Record 3 of set 11 | raudeberg
# Processing Record 4 of set 11 | chacabuco
# Processing Record 5 of set 11 | karaton
# Processing Record 6 of set 11 | laksham
# Processing Record 7 of set 11 | hirado
# Processing Record 8 of set 11 | richards bay
# Processing Record 9 of set 11 | mojo
# Processing Record 10 of set 11 | pillaro
# Processing Record 11 of set 11 | mandalgovi
# Processing Record 12 of set 11 | nizwa
# Processing Record 13 of set 11 | la ronge
# Processing Record 14 of set 11 | san rafael
# Processing Record 15 of set 11 | rawlins
# Processing Record 16 of set 11 | chardara
# City not found. Skipping...
# Processing Record 17 of set 11 | vila
# Processing Record 18 of set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 19 of set 11 | dasoguz
# Processing Record 20 of set 11 | sandwick
# Processing Record 21 of set 11 | busia
# Processing Record 22 of set 11 | shebunino
# Processing Record 23 of set 11 | lulea
# Processing Record 24 of set 11 | okhotsk
# Processing Record 25 of set 11 | kajaani
# Processing Record 26 of set 11 | mahendranagar
# Processing Record 27 of set 11 | soyo
# Processing Record 28 of set 11 | saint-pierre
# Processing Record 29 of set 11 | murgab
# Processing Record 30 of set 11 | bridlington
# Processing Record 31 of set 11 | nuuk
# Processing Record 32 of set 11 | port-gentil
# Processing Record 33 of set 11 | nakhon thai
# Processing Record 34 of set 11 | bonfim
# Processing Record 35 of set 11 | maningrida
# Processing Record 36 of set 11 | timra
# Processing Record 37 of set 11 | colimes
# Processing Record 38 of set 11 | pizarro
# Processing Record 39 of set 11 | surgut
# Processing Record 40 of set 11 | tynda
# Processing Record 41 of set 11 | murray bridge
# Processing Record 42 of set 11 | smolenka
# Processing Record 43 of set 11 | kortkeros
# Processing Record 44 of set 11 | fergus falls
# Processing Record 45 of set 11 | wajima
# Processing Record 46 of set 11 | ca mau
# Processing Record 47 of set 11 | hami
# Processing Record 48 of set 11 | davila
# Processing Record 49 of set 11 | tieli
# Processing Record 0 of set 12 | torbat-e jam
# Processing Record 1 of set 12 | along
# Processing Record 2 of set 12 | canutama
# Processing Record 3 of set 12 | bermeo
# Processing Record 4 of set 12 | blankenberge
# Processing Record 5 of set 12 | gandiaye
# Processing Record 6 of set 12 | manglisi
# Processing Record 7 of set 12 | northam
# Processing Record 8 of set 12 | thinadhoo
# Processing Record 9 of set 12 | kirakira
# Processing Record 10 of set 12 | virginia beach
# Processing Record 11 of set 12 | egvekinot
# Processing Record 12 of set 12 | la tuque
# Processing Record 13 of set 12 | bichura
# Processing Record 14 of set 12 | marsa matruh
# Processing Record 15 of set 12 | shangrao
# Processing Record 16 of set 12 | coruripe
# Processing Record 17 of set 12 | noumea
# Processing Record 18 of set 12 | shizunai
# Processing Record 19 of set 12 | chara
# Processing Record 20 of set 12 | nanchang
# Processing Record 21 of set 12 | dwarka
# Processing Record 22 of set 12 | mercedes
# Processing Record 23 of set 12 | qui nhon
# City not found. Skipping...
# Processing Record 24 of set 12 | papar
# Processing Record 25 of set 12 | kalianget
# Processing Record 26 of set 12 | tabiauea
# City not found. Skipping...
# Processing Record 27 of set 12 | lisakovsk
# Processing Record 28 of set 12 | tottori
# Processing Record 29 of set 12 | am timan
# Processing Record 30 of set 12 | jutai
# Processing Record 31 of set 12 | washington
# Processing Record 32 of set 12 | otane
# Processing Record 33 of set 12 | honiara
# Processing Record 34 of set 12 | rio gallegos
# Processing Record 35 of set 12 | lavrentiya
# Processing Record 36 of set 12 | lerik
# Processing Record 37 of set 12 | puerto ayacucho
# Processing Record 38 of set 12 | jimeta
# Processing Record 39 of set 12 | ust-nera
# Processing Record 40 of set 12 | carora
# Processing Record 41 of set 12 | santa rosalia
# Processing Record 42 of set 12 | sabratah
# Processing Record 43 of set 12 | tomatlan
# Processing Record 44 of set 12 | palmira
# Processing Record 45 of set 12 | asau
# City not found. Skipping...
# Processing Record 46 of set 12 | lahaina
# Processing Record 47 of set 12 | alyangula
# Processing Record 48 of set 12 | mogadishu
# Processing Record 49 of set 12 | pavelets
# Processing Record 0 of set 13 | horodkivka
# Processing Record 1 of set 13 | taksimo
# Processing Record 2 of set 13 | kloulklubed
# Processing Record 3 of set 13 | valparaiso
# Processing Record 4 of set 13 | marcona
# City not found. Skipping...
# Processing Record 5 of set 13 | entebbe
# Processing Record 6 of set 13 | ayr
# Processing Record 7 of set 13 | ranikhet
# Processing Record 8 of set 13 | warqla
# City not found. Skipping...
# Processing Record 9 of set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of set 13 | porbandar
# Processing Record 11 of set 13 | kerema
# Processing Record 12 of set 13 | umm lajj
# Processing Record 13 of set 13 | sauda
# Processing Record 14 of set 13 | sumbawa
# City not found. Skipping...
# Processing Record 15 of set 13 | spetsai
# City not found. Skipping...
# Processing Record 16 of set 13 | molokovo
# Processing Record 17 of set 13 | flinders
# Processing Record 18 of set 13 | rodrigues alves
# Processing Record 19 of set 13 | miraflores
# Processing Record 20 of set 13 | turayf
# Processing Record 21 of set 13 | antananarivo
# Processing Record 22 of set 13 | ouallam
# Processing Record 23 of set 13 | brigantine
# Processing Record 24 of set 13 | inuvik
#
#     ---------------------------
#     Data Retrival Complete
#     ---------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
CityData = pd.DataFrame({"City":name,"Cloudiness":cloudiness,\
                         "Country":country,"Date":date,"Humidity":humidity,"Lat":lat,"Lng":lng,\
                         "Max Temp":max_temp,"Wind Speed":wind_speed})
CityData.to_csv(output_data_file)
CityData.count()
# Out:
# City          565
# Cloudiness    565
# Country       565
# Date          565
# Humidity      565
# Lat           565
# Lng           565
# Max Temp      565
# Wind Speed    565
# dtype: int64

# %%
CityData.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Arraial do Cabo         100      BR  1562366707        88 -22.97  -42.02
# 1        Jamestown          15      AU  1562366491        61 -33.21  138.60
# 2       Chokurdakh          48      RU  1562366707        55  70.62  147.90
# 3           Atuona          22      PF  1562366707        80  -9.80 -139.03
# 4      Tuktoyaktuk          90      CA  1562366708        87  69.44 -133.03
#
#    Max Temp  Wind Speed
# 0     66.53       19.64
# 1     60.05       19.86
# 2     54.11       13.02
# 3     81.11       18.92
# 4     55.40        9.17

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
Today_date = f"0{time.gmtime()[2]}/0{time.gmtime()[1]}/{time.gmtime()[0]}"
Today_date

plt.scatter(CityData["Lat"],CityData["Max Temp"],edgecolors="black")
plt.title(f"City Latitude vs. Max Temperature ({Today_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("output_data/Max_temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(CityData["Lat"],CityData["Humidity"],edgecolors="black")
plt.title(f"City Latitude vs. Humidity ({Today_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(0,105)
plt.grid()
plt.savefig("output_data/Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(CityData["Lat"],CityData["Cloudiness"],edgecolors="black")
plt.title(f"City Latitude vs. Cloudiness ({Today_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("output_data/Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(CityData["Lat"],CityData["Wind Speed"],edgecolors="black")
plt.title(f"City Latitude vs. Wind Speed ({Today_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("output_data/Wind_speed.png")
